# %%
import numpy as np
import pandas as np
import seaborn as sns
df=sns.load_dataset('tips')
print(df)

df.groupby('sex') ['total_bill'].agg(['mean','median','min','max','std'])
df['sex']= df['sex'].map({'Male':0,'Female':1})  # Optional
print(df)

another_df=sns.load_dataset('iris')
another_df
another_df['species'].unique()

setosa = another_df[another_df['species'] == "setosa"]
versicolor = another_df[another_df['species'] == "versicolor"]
virginica = another_df[another_df['species'] == "virginica"]

setosa.describe()
versicolor.describe()
virginica.describe()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   1     No   Sun  Dinner     2
# 1         10.34  1.66   0     No   Sun  Dinner     3
# 2         21.01  3.50   0     No   Sun  Dinner     3
# ...
